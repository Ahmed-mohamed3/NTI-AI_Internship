# %%
import pandas as pd
import keras 
import numpy as np
from keras.models import *
from keras.layers import Dense
import matplotlib.pyplot as plt
from keras.datasets import cifar10

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_test = x_test.reshape((-1,3072))
x_train = x_train.reshape((-1,3072))
x_train.shape
# Out:
# (50000, 3072)

# %%
# normlize the data
x_train = x_train/255
x_test  = x_test/255

# %%
model = Sequential()
model.add(Dense(3000,input_shape=(3072,), activation="relu"))
model.add(Dense(1000, activation="relu"))
model.add(Dense(600, activation="relu"))
model.add(Dense(10, activation="softmax"))

model.compile(optimizer='sgd',loss= 'sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
#results = model.fit(x=x_train, y=y_train,shuffle=True,epochs=10)
results=model.fit(
  x=x_train,
  y=y_train,
  shuffle=True,
  epochs=5,
  validation_data=(x_test,y_test)
)
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 113s 72ms/step - loss: 2.3010 - accuracy: 0.1136 - val_loss: 2.3002 - val_accuracy: 0.1000
# Epoch 2/5
# 1563/1563 [==============================] - 113s 72ms/step - loss: 2.2997 - accuracy: 0.1361 - val_loss: 2.2990 - val_accuracy: 0.1005
# Epoch 3/5
# 1563/1563 [==============================] - 110s 70ms/step - loss: 2.2987 - accuracy: 0.1378 - val_loss: 2.2978 - val_accuracy: 0.1036
# Epoch 4/5
# 1563/1563 [==============================] - 110s 70ms/step - loss: 2.2972 - accuracy: 0.1391 - val_loss: 2.2963 - val_accuracy: 0.1382
# Epoch 5/5
# 1563/1563 [==============================] - 109s 70ms/step - loss: 2.2952 - accuracy: 0.1555 - val_loss: 2.2938 - val_accuracy: 0.1668

# %%
import matplotlib.pyplot as plt
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.legend(['Training','Vaildation'])
plt.title('Training and Validation Losses')
plt.xlabel('epoches')
plt.ylabel('losses')
# Out:
# Text(0, 0.5, 'losses')

# %%
import matplotlib.pyplot as plt
plt.plot(results.history['accuracy'])
plt.plot(results.history['val_accuracy'])
plt.legend(['Training','Vaildation'])
plt.title('Training and Validation Accuracy')
plt.xlabel('epoches')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')
