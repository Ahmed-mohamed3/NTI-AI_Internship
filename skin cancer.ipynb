# %%
cd '/content'
# Out:
# /content

# %%
! pip install -q kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ref                                                            title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# iamsouravbanerjee/world-population-dataset                     World Population Dataset                             17KB  2022-08-31 11:20:04           9164        276  1.0
# thedevastator/mcdonalds-ice-cream-machines-broken-timeseries   McDonalds Ice Cream Machines Breaking - Timeseries  404KB  2022-09-14 23:51:09            836         35  1.0
# pantanjali/unemployment-dataset                                Unemployment dataset                                 17KB  2022-09-08 08:26:10           2221         68  1.0
# evangower/premier-league-match-data                            Premier League Match Data                             8KB  2022-09-14 18:40:58            541         38  1.0
# ariyoomotade/netflix-data-cleaning-analysis-and-visualization  Netflix Data: Cleaning, Analysis and Visualization  270KB  2022-08-26 09:25:43           4644        111  1.0
# whenamancodes/world-population-live-dataset                    World Population Live Dataset 2022                   10KB  2022-09-10 11:29:21           1018         37  1.0
# iamsouravbanerjee/house-rent-prediction-dataset                House Rent Prediction Dataset                        82KB  2022-08-20 13:49:03          13933        341  1.0
# deepcontractor/smoke-detection-dataset                         Smoke Detection Dataset                               2MB  2022-08-21 06:29:34           2971         92  1.0
# moazzimalibhatti/co2-emission-by-countries-year-wise-17502022  CO2 Emission by countries Year wise (1750-2022)     280KB  2022-09-14 07:43:00            650         42  1.0
# wittmannf/top-250-imdb-series-episode-ratings                  Top 250 IMDB Series Episode Ratings in Sept 2022     92KB  2022-09-05 18:44:55            600         25  1.0
# advaypatil/youtube-statistics                                  Youtube Statistics                                    2MB  2022-08-26 02:03:19           1943         61  1.0
# muhammadadiltalay/imdb-video-games                             IMDB Video Games                                      1MB  2022-09-02 07:15:52           1115         36  0.9705882
# kaggleashwin/population-dataset                                World Population by Countries Dataset (1960-2021)    69KB  2022-08-31 05:30:26           1819         77  1.0
# csafrit2/latest-global-temperatures                            Latest Global Temperatures                           92KB  2022-09-05 01:10:12            744         28  1.0
# surajjha101/fortune-top-1000-companies-by-revenue-2022         Fortune Top 1000 Companies by Revenue 2022           37KB  2022-08-28 06:43:27           1443         56  1.0
# anuragbantu/ukraine-invasion-refugee-data-2022                 Ukraine Invasion Refugee data 2022                   19KB  2022-09-15 12:24:39            414         29  1.0
# totoro29/air-pollution-level                                   Air Pollution Level                                 394KB  2022-09-09 04:36:03           1049         29  1.0
# whenamancodes/data-science-fields-salary-categorization        Data Science Fields Salary Categorization             7KB  2022-09-10 07:53:45            554         29  1.0
# fernandoretamales/health-expenditure-and-suicide-rates         Health Expenditure and Suicide Rates [2000-2019]     45KB  2022-09-06 17:37:21            487         27  1.0
# sergylog/ab-test-data                                          A/B test data                                        28KB  2022-09-16 17:29:06            190         62  1.0

# %%
! kaggle datasets download -d 'fanconic/skin-cancer-malignant-vs-benign'
# Out:
# Downloading skin-cancer-malignant-vs-benign.zip to /content
#  99% 321M/325M [00:02<00:00, 113MB/s]
# 100% 325M/325M [00:02<00:00, 116MB/s]

# %%
! mkdir skin_cancer

# %%
! unzip  -d "/content/skin-cancer-malignant-vs-benign.zip"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
from skimage.io import imread,imshow
from skimage.transform import resize
from sklearn.utils import shuffle
from tqdm import tqdm
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer,Conv2D,MaxPool2D,BatchNormalization,Dropout,Flatten,Dense
from tensorflow.keras.callbacks import EarlyStopping
