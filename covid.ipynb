# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
! pip install -q kaggle

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ref                                                            title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# kaggleashwin/population-dataset                                World Population by Countries Dataset (1960-2021)    69KB  2022-08-31 05:30:26            992         45  1.0
# iamsouravbanerjee/house-rent-prediction-dataset                House Rent Prediction Dataset                        82KB  2022-08-20 13:49:03           8273        227  1.0
# iamsouravbanerjee/world-population-dataset                     World Population Dataset                             17KB  2022-08-31 11:20:04           2256         94  1.0
# ...

# %%
! kaggle datasets download -d pranavraikokte/covid19-image-dataset
# Out:
# covid19-image-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
! unzip covid19-image-dataset.zip -d covid19-image-dataset
# Out:
# Archive:  covid19-image-dataset.zip
# replace covid19-image-dataset/Covid19-dataset/test/Covid/0100.jpeg? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace covid19-image-dataset/Covid19-dataset/test/Covid/0102.jpeg? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace covid19-image-dataset/Covid19-dataset/test/Covid/0102.jpeg? [y]es, [n]o, [A]ll, [N]one, [r]ename:
# error:  invalid response [{ENTER}]
# replace covid19-image-dataset/Covid19-dataset/test/Covid/0102.jpeg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: covid19-image-dataset/Covid19-dataset/test/Covid/0102.jpeg
#   inflating: covid19-image-dataset/Covid19-dataset/test/Covid/0105.png
#   inflating: covid19-image-dataset/Covid19-dataset/test/Covid/0106.jpeg
#   inflating: covid19-image-dataset/Covid19-dataset/test/Covid/0108.jpeg
#   inflating: covid19-image-dataset/Covid19-dataset/test/Covid/0111.jpg
#   inflating: covid19-image-dataset/Covid19-dataset/test/Covid/0112.jpg
# ...

# %%
cd covid19-image-dataset
# Out:
# /content/covid19-image-dataset

# %%
cd Covid19-dataset
# Out:
# /content/covid19-image-dataset/Covid19-dataset

# %%
ls
# Out:
# test/  train/

# %%
cd train 
y
# Out:
#   File "<ipython-input-12-5a0898f1d5d1>", line 1
#     cd train
#            ^
# SyntaxError: invalid syntax

# %%
cd Covid
# Out:
# [Errno 2] No such file or directory: 'Covid'
# /content/covid19-image-dataset/Covid19-dataset

# %%
from PIL import Image
import glob
covid_train = []
for filename in glob.glob('/content/covid19-image-dataset/Covid19-dataset/test/Covid/*.jpeg'): 
    im=Image.open(filename)
    covid_train.append(im)
for filename in glob.glob('/content/covid19-image-dataset/Covid19-dataset/test/Covid/*.png'): 
    im=Image.open(filename)
    covid_train.append(im)
for filename in glob.glob('/content/covid19-image-dataset/Covid19-dataset/test/Covid/*.jpg'): 
    im=Image.open(filename)
    covid_train.append(im)

# %%
len(covid_train)
# Out:
# 26

# %%
from PIL import Image
import glob
Normal_train = []
for filename in glob.glob('/content/covid19-image-dataset/Covid19-dataset/train/Normal/*.jpeg'): 
    im=Image.open(filename)
    Normal_train.append(im)
for filename in glob.glob('/content/covid19-image-dataset/Covid19-dataset/train/Normal/*.png'): 
    im=Image.open(filename)
    Normal_train.append(im)
for filename in glob.glob('/content/covid19-image-dataset/Covid19-dataset/train/Normal*.jpg'): 
    im=Image.open(filename)
    Normal_train.append(im)

# %%
len(Normal_train)
# Out:
# 70

# %%
from PIL import Image
import glob
covid_test = []
for filename in glob.glob('/content/covid19-image-dataset/Covid19-dataset/test/Covid/*.jpeg'): 
    im=Image.open(filename)
    covid_test.append(im)
for filename in glob.glob('/content/covid19-image-dataset/Covid19-dataset/test/Covid/*.png'): 
    im=Image.open(filename)
    covid_test.append(im)
for filename in glob.glob('/content/covid19-image-dataset/Covid19-dataset/test/Covid/*.jpg'): 
    im=Image.open(filename)
    covid_test.append(im)

# %%
len(covid_test)
# Out:
# 26

# %%
from PIL import Image
import glob
Normal_test = []
for filename in glob.glob('/content/covid19-image-dataset/Covid19-dataset/test/Normal/*.jpeg'): 
    im=Image.open(filename)
    Normal_test.append(im)
for filename in glob.glob('/content/covid19-image-dataset/Covid19-dataset/test/Normal/*.png'): 
    im=Image.open(filename)
    Normal_test.append(im)
for filename in glob.glob('/content/covid19-image-dataset/Covid19-dataset/test/Normal/*.jpg'): 
    im=Image.open(filename)
    Normal_test.append(im)

# %%
len(Normal_test)
# Out:
# 20

# %%
from numpy import asarray
Normal_test_array = []
for image in Normal_test :
  data = asarray(image)
  Normal_test_array.append(np.array(data))

# %%
from numpy import asarray
covid_test_array = []
for image in covid_test :
  data = asarray(image)
  covid_test_array.append(np.array(data))

# %%
from numpy import asarray
covid_train_array = []
for image in covid_train :
  data = asarray(image)
  covid_train_array.append(np.array(data))

# %%
from numpy import asarray
Normal_train_array = []
for image in Normal_train :
  data = asarray(image)
  Normal_train_array.append(data)

# %%
Normal_train_array
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-a89fae8767c6> in <module>
# ----> 1 Normal_train_array.shape
#
# AttributeError: 'list' object has no attribute 'shape'
